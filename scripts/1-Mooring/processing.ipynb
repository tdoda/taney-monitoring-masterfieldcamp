# %% [markdown]
# ## Processing

# %%
# imports
from oxygen_logger import oxygen_logger

# %%
import pandas as pd
import os

# %%
df = pd.read_csv('../../data/Mooring/HOBO_P/20260603/Level0/20598412_B_15.csv')

# %%
df.columns
# Out:
# Index(['Titre de tracé : 20598412_B_15'], dtype='object')

# %%
df.columns
# Out:
# Index(['Titre de tracé : 20598412_B_15'], dtype='object')

# %%
df.columns
# Out:
# Index(['Titre de tracé : 20598412_B_15'], dtype='object')
